# %%
import pandas as pd

# %%
df=pd.read_csv('nba_draft_combine_all_years(pandas).csv')

# %%
df
# Out:
#      Unnamed: 0                 Player  Year  Draft pick  Height (No Shoes)  \
# 0             0          Blake Griffin  2009         1.0              80.50
# 1             1      Terrence Williams  2009        11.0              77.00
# 2             2       Gerald Henderson  2009        12.0              76.00
# 3             3       Tyler Hansbrough  2009        13.0              80.25
# 4             4             Earl Clark  2009        14.0              80.50
# ..          ...                    ...   ...         ...                ...
# 512         512              Peter Jok  2017         NaN              76.25
# 513         513           Rawle Alkins  2017         NaN              74.50
# 514         514  Sviatoslav Mykhailiuk  2017         NaN              78.50
# 515         515           Thomas Welsh  2017         NaN              83.50
# 516         516           V.J. Beachem  2017         NaN              78.25
#
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0         Year  Draft pick  Height (No Shoes)  \
# count  517.000000   517.000000  384.000000         517.000000
# mean   258.000000  2013.187621   28.492188          77.609284
# std    149.389312     2.531507   15.888973           3.287633
# min      0.000000  2009.000000    1.000000          68.250000
# 25%    129.000000  2011.000000   15.000000          75.250000
# 50%    258.000000  2013.000000   28.000000          77.750000
# 75%    387.000000  2015.000000   41.000000          80.000000
# max    516.000000  2017.000000   60.000000          85.250000
#
#        Height (With Shoes)    Wingspan  Standing reach  Vertical (Max)  \
# count           516.000000  517.000000      517.000000      450.000000
# mean             78.898740   82.497292      103.275629       35.136667
# std               3.275837    3.943068        4.897515        3.561688
# min              69.500000   70.000000       88.500000       25.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                517 non-null    int64
#  1   Player                    517 non-null    object
#  2   Year                      517 non-null    int64
#  3   Draft pick                384 non-null    float64
#  4   Height (No Shoes)         517 non-null    float64
#  5   Height (With Shoes)       516 non-null    float64
#  6   Wingspan                  517 non-null    float64
#  7   Standing reach            517 non-null    float64
#  8   Vertical (Max)            450 non-null    float64
#  9   Vertical (Max Reach)      450 non-null    float64
#  10  Vertical (No Step)        450 non-null    float64
#  11  Vertical (No Step Reach)  450 non-null    float64
#  12  Weight                    516 non-null    float64
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                    0
# Player                        0
# Year                          0
# Draft pick                  133
# Height (No Shoes)             0
# Height (With Shoes)           1
# Wingspan                      0
# Standing reach                0
# Vertical (Max)               67
# Vertical (Max Reach)         67
# Vertical (No Step)           67
# Vertical (No Step Reach)     67
# Weight                        1
# Body Fat                      3
# Hand (Length)                47
# Hand (Width)                 49
# Bench                       233
# Agility                      73
# Sprint                       71
# dtype: int64

# %%
df
# Out:
#      Unnamed: 0                 Player  Year  Draft pick  Height (No Shoes)  \
# 0             0          Blake Griffin  2009         1.0              80.50
# 1             1      Terrence Williams  2009        11.0              77.00
# 2             2       Gerald Henderson  2009        12.0              76.00
# 3             3       Tyler Hansbrough  2009        13.0              80.25
# 4             4             Earl Clark  2009        14.0              80.50
# ..          ...                    ...   ...         ...                ...
# 512         512              Peter Jok  2017         NaN              76.25
# 513         513           Rawle Alkins  2017         NaN              74.50
# 514         514  Sviatoslav Mykhailiuk  2017         NaN              78.50
# 515         515           Thomas Welsh  2017         NaN              83.50
# 516         516           V.J. Beachem  2017         NaN              78.25
#
# ...

# %% [markdown]
# **To count null values in Bench**

# %%
df['Bench'].isna().sum()
# Out:
# 233

# %%
df['Bench'].value_counts()
# Out:
# Bench
# 10.0    34
# 15.0    23
# 5.0     21
# 9.0     20
# 8.0     20
# 13.0    18
# 7.0     17
# 14.0    17
# 6.0     13
# 12.0    12
# 4.0     11
# 17.0    11
# 3.0     10
# 16.0    10
# 11.0    10
# 2.0      9
# 1.0      7
# 18.0     7
# 19.0     7
# 22.0     3
# 20.0     2
# 23.0     1
# 21.0     1
# Name: count, dtype: int64

# %% [markdown]
# **To count non null values in Bench**

# %%
df['Bench'].value_counts().sum()
# Out:
# 284

# %% [markdown]
# **To fill null values with mean in Bench Column**

# %%
df['Bench']=df['Bench'].fillna(value=df['Bench'].mean())

# %%
df
# Out:
#      Unnamed: 0                 Player  Year  Draft pick  Height (No Shoes)  \
# 0             0          Blake Griffin  2009         1.0              80.50
# 1             1      Terrence Williams  2009        11.0              77.00
# 2             2       Gerald Henderson  2009        12.0              76.00
# 3             3       Tyler Hansbrough  2009        13.0              80.25
# 4             4             Earl Clark  2009        14.0              80.50
# ..          ...                    ...   ...         ...                ...
# 512         512              Peter Jok  2017         NaN              76.25
# 513         513           Rawle Alkins  2017         NaN              74.50
# 514         514  Sviatoslav Mykhailiuk  2017         NaN              78.50
# 515         515           Thomas Welsh  2017         NaN              83.50
# 516         516           V.J. Beachem  2017         NaN              78.25
#
# ...

# %%
df['Bench']=df['Bench'].round(2)
df
# Out:
#      Unnamed: 0                 Player  Year  Draft pick  Height (No Shoes)  \
# 0             0          Blake Griffin  2009         1.0              80.50
# 1             1      Terrence Williams  2009        11.0              77.00
# 2             2       Gerald Henderson  2009        12.0              76.00
# 3             3       Tyler Hansbrough  2009        13.0              80.25
# 4             4             Earl Clark  2009        14.0              80.50
# ..          ...                    ...   ...         ...                ...
# 512         512              Peter Jok  2017         NaN              76.25
# 513         513           Rawle Alkins  2017         NaN              74.50
# 514         514  Sviatoslav Mykhailiuk  2017         NaN              78.50
# 515         515           Thomas Welsh  2017         NaN              83.50
# 516         516           V.J. Beachem  2017         NaN              78.25
#
# ...

# %%
df['Bench'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Repeating the Same Step for agility and Sprint**

# %%
columns_to_fill = ['Agility' , 'Sprint' ]
for column in columns_to_fill:
    df[column].fillna(value=df[column].mean(),inplace=True)

# %%
df
# Out:
#      Unnamed: 0                 Player  Year  Draft pick  Height (No Shoes)  \
# 0             0          Blake Griffin  2009         1.0              80.50
# 1             1      Terrence Williams  2009        11.0              77.00
# 2             2       Gerald Henderson  2009        12.0              76.00
# 3             3       Tyler Hansbrough  2009        13.0              80.25
# 4             4             Earl Clark  2009        14.0              80.50
# ..          ...                    ...   ...         ...                ...
# 512         512              Peter Jok  2017         NaN              76.25
# 513         513           Rawle Alkins  2017         NaN              74.50
# 514         514  Sviatoslav Mykhailiuk  2017         NaN              78.50
# 515         515           Thomas Welsh  2017         NaN              83.50
# 516         516           V.J. Beachem  2017         NaN              78.25
#
# ...

# %%
df[['Agility','Sprint']]=df[['Agility','Sprint']].round(2)

# %%
df
# Out:
#      Unnamed: 0                 Player  Year  Draft pick  Height (No Shoes)  \
# 0             0          Blake Griffin  2009         1.0              80.50
# 1             1      Terrence Williams  2009        11.0              77.00
# 2             2       Gerald Henderson  2009        12.0              76.00
# 3             3       Tyler Hansbrough  2009        13.0              80.25
# 4             4             Earl Clark  2009        14.0              80.50
# ..          ...                    ...   ...         ...                ...
# 512         512              Peter Jok  2017         NaN              76.25
# 513         513           Rawle Alkins  2017         NaN              74.50
# 514         514  Sviatoslav Mykhailiuk  2017         NaN              78.50
# 515         515           Thomas Welsh  2017         NaN              83.50
# 516         516           V.J. Beachem  2017         NaN              78.25
#
# ...

# %% [markdown]
# **To drop Unnamed : 0 Column**

# %%
a = df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
print(a)
# Out:
# None

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.drop('Unnamed: 0',axis=1,inplace=True)
#
# File c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
# ...

# %%
df
# Out:
#                     Player  Year  Draft pick  Height (No Shoes)  \
# 0            Blake Griffin  2009         1.0              80.50
# 1        Terrence Williams  2009        11.0              77.00
# 2         Gerald Henderson  2009        12.0              76.00
# 3         Tyler Hansbrough  2009        13.0              80.25
# 4               Earl Clark  2009        14.0              80.50
# ..                     ...   ...         ...                ...
# 512              Peter Jok  2017         NaN              76.25
# 513           Rawle Alkins  2017         NaN              74.50
# 514  Sviatoslav Mykhailiuk  2017         NaN              78.50
# 515           Thomas Welsh  2017         NaN              83.50
# 516           V.J. Beachem  2017         NaN              78.25
#
#      Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                  82.00     83.25           105.0            35.5
# ...

# %% [markdown]
# **Here i will fill null values in Draft Pick with the avaerage value . Actually i wont consider this Column in further Process**

# %%
df['Draft pick']=df['Draft pick'].fillna(value=df['Bench'].mean()).round(2)

# %%
df
# Out:
#                     Player  Year  Draft pick  Height (No Shoes)  \
# 0            Blake Griffin  2009        1.00              80.50
# 1        Terrence Williams  2009       11.00              77.00
# 2         Gerald Henderson  2009       12.00              76.00
# 3         Tyler Hansbrough  2009       13.00              80.25
# 4               Earl Clark  2009       14.00              80.50
# ..                     ...   ...         ...                ...
# 512              Peter Jok  2017       10.24              76.25
# 513           Rawle Alkins  2017       10.24              74.50
# 514  Sviatoslav Mykhailiuk  2017       10.24              78.50
# 515           Thomas Welsh  2017       10.24              83.50
# 516           V.J. Beachem  2017       10.24              78.25
#
#      Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                  82.00     83.25           105.0            35.5
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                     Player  Year  Draft pick  Height (No Shoes)  \
# 15            Damion James  2009       24.00              78.25
# 19         Greivis Vasquez  2009       28.00              76.75
# 35              Gani Lawal  2009       46.00              79.75
# 38          Luke Harangody  2009       52.00              78.25
# 50               John Wall  2010        1.00              74.75
# ..                     ...   ...         ...                ...
# 511            P.J. Dozier  2017       10.24              77.25
# 512              Peter Jok  2017       10.24              76.25
# 513           Rawle Alkins  2017       10.24              74.50
# 514  Sviatoslav Mykhailiuk  2017       10.24              78.50
# 516           V.J. Beachem  2017       10.24              78.25
#
#      Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 15                 79.50     84.75           106.0            37.0
# ...

# %%
df.to_csv('NBA_Cleaned_Data.csv')
